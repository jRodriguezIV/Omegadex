# %% [markdown]
# # Key Takeaways
# It's been an incredibly productive and illuminating week for John. He spent the majority of his time learning about launching EC2 instances, building AMIs, adding security and networking, and designing his first project using EC2 instances as the building block of the workload.
#
# Choose each of the numbered markers to see why John has included these AWS services in his design. After you have selected the first marker, you can use the < > arrow keys to navigate through the remaining markers.
#
# ![image.png](attachment:image.png)
#
# John is also working with the networking team to discuss inbound security group rules, ports that can and cannot be open, and how to use network ACL permissions(opens in a new tab) to secure the environment. John is using Amazon VPC IP Address Manager (IPAM)(opens in a new tab) to ensure that no duplicate ranges exist in the current on-premises environment. Duplication of CIDR ranges is not advised because it causes a number of routing and application issues.
#
# Arnav, in the finance department, is helping John with his AWS purchasing options. They are running a number of different options through the AWS Pricing Calculator to estimate what a variety of different instance types and configurations might cost. Arnav is also advising John on which purchasing option or Spot Instance price is best for the budget.
#
# John is keeping the service quotas in mind to allow for his AWS environment to grow. He will reach out to AWS for quota increases should he need additional vCPUs or more than five Elastic IP addresses in the future.
